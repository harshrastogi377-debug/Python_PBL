# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df=pd.read_csv("online_purchase_500_updated.csv")
df
# Out:
#      Browsing_Time  Clicks  Product_Views  Cart_Additions  Previous_Purchases  \
# 0                7       2              2             2.0                 NaN
# 1               20       2              6             1.0                 0.0
# 2               29       7              1             4.0                 3.0
# 3               15       6             15             3.0                 0.0
# 4               11       3             10             3.0                 NaN
# ..             ...     ...            ...             ...                 ...
# 495             12       2             11             5.0                 2.0
# 496             19       2              8             0.0                 3.0
# 497             23      14             10             2.0                 4.0
# 498             15      11              7             5.0                 NaN
# 499             28       3              3             2.0                 1.0
#
#      Time_on_Product_Page  Bounce_Rate  Discount_Viewed  Purchase
# 0                    16.0         0.51                1         0
# 1                   115.0         0.45                1         0
# 2                    53.0         0.22                1         0
# 3                    46.0         0.36                0         0
# 4                     NaN         0.45                0         0
# ..                    ...          ...              ...       ...
# 495                  34.0         0.54                0         0
# 496                  62.0         0.53                0         0
# 497                 106.0         0.71                0         0
# 498                  35.0         0.77                1         0
# 499                   NaN         0.45                1         0
#
# [500 rows x 9 columns]

# %%
df.describe()
# Out:
#        Browsing_Time      Clicks  Product_Views  Cart_Additions  \
# count     500.000000  500.000000     500.000000      450.000000
# mean       15.112000    7.440000       9.676000        2.935556
# std         8.850317    4.119264       5.576488        1.977114
# min         1.000000    1.000000       1.000000        0.000000
# 25%         7.000000    4.000000       5.000000        1.000000
# 50%        16.000000    7.000000       9.000000        3.000000
# 75%        23.000000   11.000000      15.000000        5.000000
# max        29.000000   14.000000      19.000000        6.000000
#
#        Previous_Purchases  Time_on_Product_Page  Bounce_Rate  Discount_Viewed  \
# count          450.000000            450.000000   500.000000       500.000000
# mean             1.986667             58.700000     0.495400         0.484000
# std              1.446846             34.634409     0.229004         0.500244
# min              0.000000              5.000000     0.100000         0.000000
# 25%              1.000000             26.250000     0.310000         0.000000
# 50%              2.000000             56.000000     0.490000         0.000000
# 75%              3.000000             90.000000     0.690000         1.000000
# max              4.000000            119.000000     0.900000         1.000000
#
#          Purchase
# count  500.000000
# mean     0.242000
# std      0.428723
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
print("Shape:", df.shape)
print("\nColumns:\n", df.columns)
print("\nInfo:\n")
df.info()
# Out:
# Shape: (500, 9)
#
# Columns:
#  Index(['Browsing_Time', 'Clicks', 'Product_Views', 'Cart_Additions',
#        'Previous_Purchases', 'Time_on_Product_Page', 'Bounce_Rate',
#        'Discount_Viewed', 'Purchase'],
#       dtype='object')
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Browsing_Time         500 non-null    int64
#  1   Clicks                500 non-null    int64
#  2   Product_Views         500 non-null    int64
#  3   Cart_Additions        450 non-null    float64
#  4   Previous_Purchases    450 non-null    float64
#  5   Time_on_Product_Page  450 non-null    float64
#  6   Bounce_Rate           500 non-null    float64
#  7   Discount_Viewed       500 non-null    int64
#  8   Purchase              500 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.head()
# Out:
#    Browsing_Time  Clicks  Product_Views  Cart_Additions  Previous_Purchases  \
# 0              7       2              2             2.0                 NaN
# 1             20       2              6             1.0                 0.0
# 2             29       7              1             4.0                 3.0
# 3             15       6             15             3.0                 0.0
# 4             11       3             10             3.0                 NaN
#
#    Time_on_Product_Page  Bounce_Rate  Discount_Viewed  Purchase
# 0                  16.0         0.51                1         0
# 1                 115.0         0.45                1         0
# 2                  53.0         0.22                1         0
# 3                  46.0         0.36                0         0
# 4                   NaN         0.45                0         0

# %%
df.tail()
# Out:
#      Browsing_Time  Clicks  Product_Views  Cart_Additions  Previous_Purchases  \
# 495             12       2             11             5.0                 2.0
# 496             19       2              8             0.0                 3.0
# 497             23      14             10             2.0                 4.0
# 498             15      11              7             5.0                 NaN
# 499             28       3              3             2.0                 1.0
#
#      Time_on_Product_Page  Bounce_Rate  Discount_Viewed  Purchase
# 495                  34.0         0.54                0         0
# 496                  62.0         0.53                0         0
# 497                 106.0         0.71                0         0
# 498                  35.0         0.77                1         0
# 499                   NaN         0.45                1         0

# %%
df.isnull().sum()
# Out:
# Browsing_Time            0
# Clicks                   0
# Product_Views            0
# Cart_Additions          50
# Previous_Purchases      50
# Time_on_Product_Page    50
# Bounce_Rate              0
# Discount_Viewed          0
# Purchase                 0
# dtype: int64

# %%
df["Cart_Additions"] = df["Cart_Additions"].fillna(df["Cart_Additions"].mean())
df["Previous_Purchases"]=df["Previous_Purchases"].fillna(df["Previous_Purchases"].mean())
df["Time_on_Product_Page"]=df["Time_on_Product_Page"].fillna(df["Time_on_Product_Page"].mean())

# %%
df.isnull().sum()
# Out:
# Browsing_Time           0
# Clicks                  0
# Product_Views           0
# Cart_Additions          0
# Previous_Purchases      0
# Time_on_Product_Page    0
# Bounce_Rate             0
# Discount_Viewed         0
# Purchase                0
# dtype: int64

# %%
df
# Out:
#      Browsing_Time  Clicks  Product_Views  Cart_Additions  Previous_Purchases  \
# 0                7       2              2             2.0                 2.0
# 1               20       2              6             1.0                 0.0
# 2               29       7              1             4.0                 3.0
# 3               15       6             15             3.0                 0.0
# 4               11       3             10             3.0                 2.0
# ..             ...     ...            ...             ...                 ...
# 495             12       2             11             5.0                 2.0
# 496             19       2              8             0.0                 3.0
# 497             23      14             10             2.0                 4.0
# 498             15      11              7             5.0                 2.0
# 499             28       3              3             2.0                 1.0
#
#      Time_on_Product_Page  Bounce_Rate  Discount_Viewed  Purchase
# 0                    16.0         0.51                1         0
# 1                   115.0         0.45                1         0
# 2                    53.0         0.22                1         0
# 3                    46.0         0.36                0         0
# 4                    56.0         0.45                0         0
# ..                    ...          ...              ...       ...
# 495                  34.0         0.54                0         0
# 496                  62.0         0.53                0         0
# 497                 106.0         0.71                0         0
# 498                  35.0         0.77                1         0
# 499                  56.0         0.45                1         0
#
# [500 rows x 9 columns]

# %%
plt.figure()
plt.hist(df["Browsing_Time"], bins=15)
plt.xlabel("Browsing Time (in minutes)")   
plt.ylabel("Number of Users")              
plt.title("Distribution of Browsing Time")
plt.show()

# %%
plt.figure()
plt.hist(df["Product_Views"], bins=10)
plt.xlabel("Number of Product Views")
plt.ylabel("Frequency of Users")
plt.title("Distribution of Product Views")
plt.show()

# %%
plt.figure()
df["Purchase"].value_counts().plot(kind="bar")
plt.xlabel("Purchase Outcome (0 = No, 1 = Yes)")
plt.ylabel("Number of Users")
plt.title("Purchase Distribution")
plt.show()

# %%
plt.figure()
plt.scatter(df["Cart_Additions"], df["Purchase"])
plt.xlabel("Number of Cart Additions")
plt.ylabel("Purchase Outcome")
plt.title("Cart Additions vs Purchase")
plt.show()

# %%
plt.figure()
corr = df.corr()
plt.imshow(corr)
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Feature Correlation Matrix")
plt.show()

# %%
numeric_columns=['Browsing_Time', 'Clicks', 'Product_Views', 'Cart_Additions',
       'Previous_Purchases', 'Time_on_Product_Page', 'Bounce_Rate']
for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col],kde=True)

# %%
numeric_columns=['Browsing_Time', 'Clicks', 'Product_Views', 'Cart_Additions',
       'Previous_Purchases', 'Time_on_Product_Page', 'Bounce_Rate']
for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])

# %%
# Loop through all columns except target
for col in df.columns[:-1]:   # excluding 'Purchase'
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    print(f"{col} -> Number of Outliers: {outliers.shape[0]}")
# Out:
# Browsing_Time -> Number of Outliers: 0
# Clicks -> Number of Outliers: 0
# Product_Views -> Number of Outliers: 0
# Cart_Additions -> Number of Outliers: 0
# Previous_Purchases -> Number of Outliers: 0
# Time_on_Product_Page -> Number of Outliers: 0
# Bounce_Rate -> Number of Outliers: 0
# Discount_Viewed -> Number of Outliers: 0

# %%
cols_to_scale = ["Browsing_Time","Clicks","Product_Views","Cart_Additions","Previous_Purchases","Time_on_Product_Page","Bounce_Rate"]
scaler = StandardScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
df
# Out:
#      Browsing_Time    Clicks  Product_Views  Cart_Additions  \
# 0        -0.917495 -1.321947      -1.377872       -0.502757
# 1         0.552850 -1.321947      -0.659856       -1.036469
# 2         1.570781 -0.106922      -1.557376        0.564667
# 3        -0.012668 -0.349927       0.955679        0.030955
# 4        -0.465081 -1.078942       0.058159        0.030955
# ..             ...       ...            ...             ...
# 495      -0.351978 -1.321947       0.237663        1.098380
# 496       0.439746 -1.321947      -0.300849       -1.570181
# 497       0.892160  1.594112       0.058159       -0.502757
# 498      -0.012668  0.865098      -0.480353        1.098380
# 499       1.457677 -1.078942      -1.198368       -0.502757
#
#      Previous_Purchases  Time_on_Product_Page  Bounce_Rate  Discount_Viewed  \
# 0              0.008752             -1.292394     0.063818                1
# 1             -1.449954              1.723090    -0.198448                1
# 2              0.738105             -0.165395    -1.203802                1
# 3             -1.449954             -0.378611    -0.591848                0
# 4              0.008752             -0.074016    -0.198448                0
# ..                  ...                   ...          ...              ...
# 495            0.008752             -0.744124     0.194951                0
# 496            0.738105              0.108740     0.151240                0
# 497            1.467458              1.448955     0.938039                0
# 498            0.008752             -0.713665     1.200306                1
# 499           -0.720601             -0.074016    -0.198448                1
#
#      Purchase
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 495         0
# 496         0
# 497         0
# 498         0
# 499         0
#
# [500 rows x 9 columns]

# %%
plt.hist(df["Browsing_Time"], bins=10)
plt.xlabel("Standardized Browsing Time")
plt.ylabel("Frequency")
plt.title("Browsing Time Distribution (After Scaling)")
plt.show()

# %%
plt.hist(df["Product_Views"], bins=10)
plt.xlabel("Standardized Product Views")
plt.ylabel("Frequency")
plt.title("Product Views Distribution")
plt.show()

# %%
df["Purchase"].value_counts().plot(kind="bar")
plt.xlabel("Purchase (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Purchase Distribution")
plt.show()

# %%
for col in df.columns[:-1]:   # excluding 'Purchase'
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    print(f"{col} -> Number of Outliers: {outliers.shape[0]}")
# Out:
# Browsing_Time -> Number of Outliers: 0
# Clicks -> Number of Outliers: 0
# Product_Views -> Number of Outliers: 0
# Cart_Additions -> Number of Outliers: 0
# Previous_Purchases -> Number of Outliers: 0
# Time_on_Product_Page -> Number of Outliers: 0
# Bounce_Rate -> Number of Outliers: 0
# Discount_Viewed -> Number of Outliers: 0

# %%
corr = df.corr()
print(corr)
# Out:
#                       Browsing_Time    Clicks  Product_Views  Cart_Additions  \
# Browsing_Time              1.000000 -0.025266       0.057990       -0.035706
# Clicks                    -0.025266  1.000000      -0.006431        0.076198
# Product_Views              0.057990 -0.006431       1.000000        0.028857
# Cart_Additions            -0.035706  0.076198       0.028857        1.000000
# Previous_Purchases        -0.027937 -0.004381      -0.032716       -0.025184
# Time_on_Product_Page      -0.019079 -0.019594      -0.002311       -0.064133
# Bounce_Rate                0.027792  0.026559      -0.045501        0.054528
# Discount_Viewed            0.043407  0.062747      -0.003299       -0.089633
# Purchase                   0.504099 -0.021833       0.537475        0.002537
#
#                       Previous_Purchases  Time_on_Product_Page  Bounce_Rate  \
# Browsing_Time                  -0.027937             -0.019079     0.027792
# Clicks                         -0.004381             -0.019594     0.026559
# Product_Views                  -0.032716             -0.002311    -0.045501
# Cart_Additions                 -0.025184             -0.064133     0.054528
# Previous_Purchases              1.000000             -0.009749    -0.023258
# Time_on_Product_Page           -0.009749              1.000000    -0.058215
# Bounce_Rate                    -0.023258             -0.058215     1.000000
# Discount_Viewed                -0.029469             -0.071563    -0.010440
# Purchase                       -0.022302             -0.007258    -0.011908
#
#                       Discount_Viewed  Purchase
# Browsing_Time                0.043407  0.504099
# Clicks                       0.062747 -0.021833
# Product_Views               -0.003299  0.537475
# Cart_Additions              -0.089633  0.002537
# Previous_Purchases          -0.029469 -0.022302
# Time_on_Product_Page        -0.071563 -0.007258
# Bounce_Rate                 -0.010440 -0.011908
# Discount_Viewed              1.000000  0.013418
# Purchase                     0.013418  1.000000

# %%
print(corr["Purchase"])
# Out:
# Browsing_Time           0.504099
# Clicks                 -0.021833
# Product_Views           0.537475
# Cart_Additions          0.002537
# Previous_Purchases     -0.022302
# Time_on_Product_Page   -0.007258
# Bounce_Rate            -0.011908
# Discount_Viewed         0.013418
# Purchase                1.000000
# Name: Purchase, dtype: float64

# %%
selected_features = []

for col in corr.columns:
    if col != "Purchase":
        if abs(corr[col]["Purchase"]) > 0.1:
            selected_features.append(col)

print("Selected Features:", selected_features)
# Out:
# Selected Features: ['Browsing_Time', 'Product_Views']
